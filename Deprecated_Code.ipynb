# %%
def is_empty_string(part: str):
    return (not part or len(part) <= 0 or part == '' or '\r' in part or '\n' in part or part == None)

def clean_string(item: str):
    return ''.join(item.split())

# %%
#                 print(DomainUrlEntityTemplate.dictionary)
#                 print('fin.read: ', len(content))
#                 print('Section: ', len(SectionEntityTemplate.dictionary))
#                 print('Url: ', len(UrlEntityTemplate.dictionary))
#                 print('DomainUrl: ', len(DomainUrlEntityTemplate.dictionary))
#                 print('OrderedList: ', len(OrderedListEntityTemplate.dictionary))
#                 print('ThreeDots: ', len(ThreeDotsEntityTemplate.dictionary))

# %%
content = '''tion title="Historija.">
Sopron je prvi put dokumentiran 1153. kao Suprun, kako se zvao upravitelj njegova zamka. 
<section title="Pobratimski gradovi.">
, Bad Wimpfen
, Banská Štiavnica
, Bolzano
, Eisenstadt
; Bolzano
; Eisenstadt
. Bolzano
.  Eisenstadt
.Bolzano
, Eisenstadt
., , Bolzano
, Eisenstadt

, Wiener Neustadt
<section title="Vanjske veze.">
"Službene stranice Soprona"'''

print(content)

# %%
content = '''<doc id="4559231" url="https://sh.wikipedia.org/wiki?curid=4559231" title="Brocardove tačke u trouglu">
Brocardove tačke u trouglu
Ime su dobile po francuskom matematičaru Henri Brocardu (1845 - 1922). 
U trougluformula_1 tačka P je prva Brokardova tačka ako važi da su uglovi između duži formula_2, formula_3 i formula_4 i stranica formula_5, formula_6 i formula_7 redom, jednaki, tj. 
Tačka P je prva Brokardova tačka u trouglu formula_1, a ugao formula_10 Brokardov ugao trougla. 
Postoji i druga Brokardova tačka formula_11, trougla formula_1 takva da su jednaki uglovi između duži formula_13, formula_14, formula_15 i stranica formula_7, formula_5 iformula_6 redom, tj. 
Teorema
Za svaki trougao postoje prva i druga Brokardova tačka. 
Dokaz
Pretpostavimo da je T tačka takva da važi formula_20
tada je
Dobijamo da tačka T pripada geometrijskom mjestu tačaka, tj. ona je na luku pod kojim se duž formula_22 vidi pod istim uglom. Nacrtajmo cijelu kružnicu koja prolazi kroz tačke formula_23, formula_24, formula_25. To je formula_26. Na isti način nacrtajmo kružnicu formula_27. 
Izabereno tačku U tako da važi:
U presjeku ove dvije kružnice dobijamo prvu Brokardovu tačku, jer za presječnu tačku formula_29 važi:
Drugu Brokardovu tačku nalazimo analogno
Za Brokardov ugao ω važi jednakost:
Dokaz
Obilježimo sa P Brokardovu tačku trougla formula_1. Iz sinusne teoreme dobijamo da važi:
i
Iz ranije dokazanog
i
Dijeljenjem prve jednačine sa drugom dobijamo da je
formula_38
Iz sinusne teoreme znamo da važi
Daljim sređivanjem dobijamo traženo tvrđenje. 
Teorema
Važi: formula_42 gde je P površina trougla formula_1. '''

# content = re.sub(r'^formula_[0-9]+\,*', '', content, flags=re.IGNORECASE | re.UNICODE | re.MULTILINE)
print(content)

# %%
content = '''google.com
google.org

www.cambridgehockey.com - Todd Jones: "Zgodovina hokeja v Cambridgu"

google.mk
google.ukim.mk.uk
google.sl
google.co.sl
google.bg
google.co.bg
google.ul.ul

magix.ai
time.gov.mk
time.gov.ddd
time.goc.mk
<doc id="213246" url="https://sl.wikipedia.org/wiki?curid=213246" title="John Ashley">
John Ashley
John Astley
</doc>
<doc id="213247" url="https://sl.wikipedia.org/wiki?curid=213247" title="Trapani (pokrajina)">
Trapani (pokrajina)
</doc>
<doc id="213250" url="https://sl.wikipedia.org/wiki?curid=213250" title="Prizorišča lige NHL">
Prizorišča lige NHL
<doc id="213254" url="https://sl.wikipedia.org/wiki?curid=213254" title="Galt Rockets">
Galt Rockets
'''

print(content)

# %%
content = '''
[[Papež Urban VIII. ]] je naročil [[Gian Lorenzo Bernini| Berniniju]],
[[File:Bnf059. jpg|thumb| Slavnostni vstop francoskega kralja Ludvika XII. v Genovo po obleganju. Miniatura Jeana Bourdichona, c. 1508]]
<section title="Ikonografska analiza.">
[[File:Catedra15. JPG|thumb|right|Prizor iz Jožefove zgodbe]]
Maksimijanov prestol simbolizira sedež oblasti in statusa. Priznan je kot sedež nekoga z močjo v srednjeveškem času. Stol ne pomeni le počitek telesa, temveč tudi osredotočenje uma. V postavitvi, kot je stolnica stol odraža versko in duhovno stališče pripadnikov cerkve. [[Katedra]] je uradni sedež škofa. 
Na prestolu so prizori stare in nove zaveze, ki prikazujejo zgodbo o Jožefu in Kristusovem življenju. Prizorišča [[Nova zaveza|Nove zaveze]] imajo značilno podobo egipčanskih primerov novih zavez in se v sedmem stoletju nadaljujejo na koptskih spomenikih
[[File:Catedra14. JPG|thumb|Drug Jožefov prizor]]
[[File:Yaroslavl gospel. jpg|thumb|left|260px|Jaroslavski evangeliji iz 13. stoletja, z zavesami v ciboriju v središču; pogost motiv v evangeličanskih portretih]]
[[File:Master Of Saint Gilles - The Mass of St Gilles - WGA14485. jpg|thumb| Zelene zavese zapete s kovinsko zaponko na sliki "La Messe de Saint Gilles" v samostanu Saint-Denis, delo mojstra iz Saint Gilesa]][[File:Bernini Baldachino. jpg|thumb|Berninijev "Baldacchino" v ]]
 da oblikuje in zgradi veliko strukturo, ki bi bila postavljena nad glavnim oltarjem, ki naj bi bil nad grobnico sv. Petra v novi cerkvi sv. Petra. Nadstrešek v bronu posnema tkanino, kot tudi številna naknadna posnemanja. Ta znana in spektakularna značilnost se običajno imenuje "Baldacchino", čeprav je to ciborij. 
Berninijevo oblikovanje Baldacchina ima velikanske solomonove stebre, navdihnjene s stebri, ki so obkrožali oltar starega svetega Petra. Te stebre je prvotno podaril [[Konstantin I. Veliki |Konstantin I. ]], in napačna tradicija trdi, da so bili stebri iz Jeruzalemskega templja. Najnižji deli štirih stebrov Berninijevega Baldachina imajo vijačni utor, srednji in zgornji del stebrov pa sta prekrita z oljčnimi in lovorovimi vejami, z množico čebel in majhnimi [[Putto |putti]]. Družinski grb papeža Urbana VIII., tisti iz družine Barberini, s svojimi znaki čebelami, so na dnu vsakega stebra. 
Vse to se združi, da ustvari občutek dvigovanja. 
<section title="Procesijska nadstrešnica.">
[[File:Bnf059. jpg|thumb| Slavnostni vstop francoskega kralja Ludvika XII. v Genovo po obleganju. Miniatura Jeana Bourdichona, c. 1508]]
<section title="Priimek Baldacchino.">
Priimek Baldacchino prihaja od obrtnikov, ki so včasih izdelovali baldahine. Priimek najdemo predvsem na otokih [[Malta]] in [[Sicilija]], zlasti v [[Agrigento|Agrigentu]] in Naru. 
<section title="Literatura.">
Baldachinum of the Altar, John Bertram Peterson, volume 2
<section title="Zunanje povezave.">
Burgundian example, King René's Tournament Book, Bibliothèque nationale de France
[[Kategorija:Cerkvena arhitektura]]
[[Kategorija:Arhitekturni elementi]]
[[Kategorija:Notranja arhitektura]]
[[Kategorija:Tekstil]]
</doc>
<doc id="452446" url="https://sl.wikipedia.org/wiki?curid=452446" title="Tanja Potočnik">
Tanja Potočnik
'''
    
SquareBracketEntityTemplate = EntityTemplate(entity_name='SquareBracket', 
                                             entity_regex=r'\[{2}([^\]\]]*)\]{2}',
                                             group_to_capture=1,
                                            do_split=True,
                                            split_string='|')

content = SquareBracketEntityTemplate.entity_to_template(content)
content = SquareBracketEntityTemplate.template_to_entity(content)
print(SquareBracketEntityTemplate.dictionary)
print(colored(content, attrs=['bold']))

# %%
    
###


content = '''
Section::::Литература. , Христо Смирненски "Песни", Скопје, 1980. , Христо Смирненски "Избор", Скопје, 1998.
Section::::Надворешни врски. 
1. a
2. f
3. v


1.a
2.f
3.v
2 

1  f
3  f
2  v

1-vcv
2-vc
3-vcv

- dsad
-dsa dsa
-dsa da
- dsadas

there are 30 apples here
2 for each

1.sdfdsf
1.
3

BULLET::::1. <a href="%D0%91%D1%80%D0%B0%D0%BD%D0%B4%D1%85%D0%BE%D1%80%D1%81%D1%82">Брандхорст</a> (102)
BULLET::::2. <a href="%D0%93%D0%BE%D1%80%D0%B0%D1%83">Горау</a> (427)
BULLET::::3. <a href="%D0%93%D1%80%D0%B8%D0%B7%D0%B5%D0%BD">Гризен</a> (364)
BULLET::::4. <a href="%D0%A5%D0%BE%D1%80%D1%81%D1%82%D0%B4%D0%BE%D1%80%D1%84">Хорстдорф</a> (633)
BULLET::::5. <a href="%D0%9A%D0%B0%D0%BA%D0%B0%D1%83">Какау</a> (609)
BULLET::::6. <a href="%D0%9E%D1%80%D0%B0%D0%BD%D0%B8%D0%BD%D0%B1%D0%B0%D1%83%D0%BC%20%28%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8%D1%98%D0%B0%29">Оранинбаум</a> (3.439)
BULLET::::7. <a href="%D0%A0%D0%B5%D0%B7%D0%B5%D0%BD">Резен</a> (272)
BULLET::::8. <a href="%D0%A0%D0%B8%D0%B7%D0%B8%D0%B3%D0%BA">Ризигк</a> (215)
BULLET::::9. <a href="%D0%A4%D0%BE%D0%BA%D0%B5%D1%80%D0%BE%D0%B4%D0%B5">Фокероде</a> (1.682)
BULLET::::10. <a href="%D0%92%D0%B5%D1%80%D0%BB%D0%B8%D1%86">Верлиц</a> (1.601)


Верлицер Винкел бил "заедница на општини" во округот Витенберг, во Саксонија-Анхалт, Германија.  Се наоѓа на левиот брег на реката Елба, источно од Десау.  Седиштето на "заедницата на општини" било во Оранинбаум.  Била распуштена во јануари 2011.
"Заедницата на општини" Верлицер Винкел се состои од следниве општини: (население за 2005 во заградите):
1.  Брандхорст (102)
2.  Горау (427)
3.  Гризен (364)
4.  Хорстдорф (633)
5.  Какау (609)
6.  Оранинбаум (3.439)
7.  Резен (272)
8.  Ризигк (215)
9.  Фокероде (1.682)
10.  Верлиц (1.601)
на Викиизвор. , Две песни од Смирненски на македонски, Уметност од Христо Смирненски на страницата www. slovo. bg, Уметност од Христо Смирненски на страницата liternet. bg'''

SectionEntityTemplate = EntityTemplate(entity_name='Section', entity_regex=r'(\bSection\b\:{4})(.+)', 
     group_to_capture=2, wrapper_string='<section title=\"{}\">')

OrderedListEntityTemplate = EntityTemplate(entity_name='OrderedList',
                entity_regex=r'^([-\d+][\. \t]*)([^\r\n]+)(?=[\r\n]*)', 
                groups_to_concat=[1, 2])

BulletListEntityTemplate = EntityTemplate(entity_name='BulletList',
                entity_regex=r'^(\bBULLET\b\:{4})([^\r\n]+)(?=[\r\n]*)',
                groups_to_concat=[2], joiner_string='JOINED')

# content = SectionEntityTemplate.entity_to_template(content)
# content = OrderedListEntityTemplate.entity_to_template(content)
content = BulletListEntityTemplate.entity_to_template(content)

# content = SectionEntityTemplate.template_to_entity(content)
# content = OrderedListEntityTemplate.template_to_entity(content)
content = BulletListEntityTemplate.template_to_entity(content)
print(content)

# re.findall(r'^([-\d+][\. \t]*)([^\r\n]+)(?=[\r\n]*)', content, flags=re.MULTILINE)

# %%
# %%time

content = '''SectionЛитература. , Христо Смирненски "Песни", Скопје, 1980. , Христо Смирненски "Избор", Скопје, 1998.
SectionНадворешни врски. , на Викиизвор. , Две песни од Смирненски на македонски, Уметност од Христо Смирненски на страницата www. slovo. bg, Уметност од Христо Смирненски на страницата liternet. bg'''

# Generating multiple regex clauses
for sign in '.,:;%!?$()':
    regex = r'[{}][ \t\f\r]*[.,:;%!?$()]'.format(sign)
    content = re.sub(regex, sign, content)
print(content)

# %%
section_pattern = re.compile(r'(\bSection\b\:{4})(.+)', re.IGNORECASE)

def fn_section_to_tag(match):
    title = match.group(2).strip()
    return '<section title=\'{title}\'>'.format(title=title)

# %%
import pathlib

subdirectory = os.path.join(defs.OUTPUT_DIR, 'mk', 'text_4', 'AA')

if not os.path.isdir(subdirectory):
    pathlib.Path(subdirectory).mkdir(parents=True, exist_ok=True)
    
    destionation_file = os.path.join(subdirectory, 'filip')
    with codecs.open(destionation_file, 'w', 'utf-8') as fout:

        content = 'Filip Markoski'
        fout.write(content)

# %%
content = '''Section::::Историја.
Section::::Постара историја.
Први познати племиња на територијата на денешна Хрватска биле Илирите и Келтите во внатрешноста, како и Хистрите, Либурните, Јаподите и Далматите на јадранскиот брег.  Во 4 век п.н.е.  на јужен и среден Јадран се создале грчки колонии, а во I век п.н.е.  територијата постепено станала дел од Римското Царство.  Најроманизирани биле Истра и провинцијата Далмација, словенски Хрвати се населиле во 7 и 8 век, римски останале само островите, како и градовите во Далмација и Истра.  Доселениците набрзо го примиле христијанството, а во Нин уште во 9 век е создадена првата хрватска бискупија.  Спорот помеѓу Византија и државата на Франките на Карло Велики завршил со Мирот во Ахен (812 г., со која далматските градови ги задржала Византија, а другите области ги добиле Франките.  На јакнеењето на нивната власт безуспешно се обидел да се cпротистави кнезот Људевит Посавски (819—822 г..
Section::::Првата хрватска држава.
Во 9 век меѓу Цетина и Велебит, се создало јадрото на хрватската држава, од каде за време на владеењето на домашните кнезови од семејството наследници на кнезот Трпимир (845—864 г. постепено се проширила на далматските градови (околу 1018—1107 г.  под власта на Венецијанците) '''
section_pattern = re.compile(r'(\bSection\b\:{4})(.+)', re.IGNORECASE)

def fn_section_to_tag(match):
    return '<section title=\'{title}\'>'.format(title=match[2])

result = section_pattern.sub(fn_section_to_tag, content)
print(result)

# %%
            # Generating multiple regex clauses
            for sign in '.,:;%!?$()':
               regex = r'[{}][ \t\f\r]*[.,:;%!?$()]'.format(sign)
               content = re.sub(regex, sign, content)

# %%
def iterate_item(item):
    process = multiprocessing.current_process().name
    print(f'[{process}]: Begining to iterate item - {item}\n')
    try:
        # Confirm the existence of the item
        print(colored(text=f'\t[{process}]: Iterating item - {item}\n', color='green'))
    except ValueError as error:
        print(colored(text=f'\t[{process}]: Error found at item - {item}, {error}', color='red'))
        return item

# %%
file_prefix = 'wiki_'
    
    # Generating the file names
    items = list()
    for i in range(15):
        items.append(f'{file_prefix}{i:02d}')
    
    print(items)

# %%
# \[\%\_\_[U][R][L]\_[0-9]\_\_\%\]

def generate_template_regex(injection):
    template_regex_injection = r''
    for character in injection:
        if character.isalpha():
            template_regex_injection += f'[{character}]'
    regex_string = BASE_TEMPLATE_REGEX.format(injection=template_regex_injection)
    return  re.compile(regex_string, re.IGNORECASE)
generate_template_regex(URL_TEMPLATE_STRING)

# Regular Expressions
url_pattern = re.compile(r'[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&\/=]*)', re.IGNORECASE)


# Template language
BASE_TEMPLATE_STRING = '[%__{injection}_{{}}__%]'
URL_TEMPLATE_STRING = BASE_TEMPLATE_STRING.format(injection='URL')
ORDERED_LIST_TEMPLATE_STRING = BASE_TEMPLATE_STRING.format(injection='ORDEREDLIST')
SECTION_TEMPLATE_STRING = BASE_TEMPLATE_STRING.format(injection='SECTION')

# Corresponding Template regular expressions
BASE_TEMPLATE_REGEX = '\[\%\_\_{injection}\_[0-9]\_\_\%\]'
URL_TEMPLATE_REGEX = generate_template_regex(URL_TEMPLATE_STRING)
ORDERED_LIST_TEMPLATE_REGEX = generate_template_regex(ORDERED_LIST_TEMPLATE_STRING)
SECTION_TEMPLATE_REGEX = generate_template_regex(SECTION_TEMPLATE_STRING)

print(BASE_TEMPLATE_STRING, BASE_TEMPLATE_REGEX)
print(URL_TEMPLATE_STRING.format(3), URL_TEMPLATE_REGEX)
print(ORDERED_LIST_TEMPLATE_STRING.format(4), ORDERED_LIST_TEMPLATE_REGEX)
print(SECTION_TEMPLATE_STRING.format(3), SECTION_TEMPLATE_REGEX)

# %%
content = '''SectionЛитература. , Христо Смирненски "Песни", Скопје, 1980. , Христо Смирненски "Избор", Скопје, 1998.
SectionНадворешни врски. , на Викиизвор. , Две песни од Смирненски на македонски, Уметност од Христо Смирненски 
на страницата www.slovo.bg, Уметност од Христо Смирненски на страницата liternet.bg
smeshno e superlongstring.com
lapajsi.com.mk, ahaha.com
slobodno odete na finki.ukim.mk
time.mk i mnogu drugi koi zavrshuvaat so mk ili .mk ili .org'''

urls = dict()
url_counter = 0
def fn_url_to_template_replace(match):
    global url_counter
    urls[url_counter] = (match.group(), match.start(), match.end())
    substitution = URL_TEMPLATE_STRING.format(url_counter)
    url_counter += 1
    return substitution

print(UrlEntityTemplate.entity_regex.sub(fn_url_to_template_replace, content))
print()
print(urls)

# %%
# %%time

url_pattern = re.compile(r'[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&\/=]*)', re.IGNORECASE)

content = '''SectionЛитература. , Христо Смирненски "Песни", Скопје, 1980. , Христо Смирненски "Избор", Скопје, 1998.
SectionНадворешни врски. , на Викиизвор. , Две песни од Смирненски на македонски, Уметност од Христо Смирненски 
на страницата www.slovo.bg, Уметност од Христо Смирненски на страницата liternet.bg
smeshno e superlongstring.com lapajsi.com.mk, ahaha.com slobodno odete na finki.ukim.mk 
time.mk i mnogu drugi koi zavrshuvaat so mk ili .mk ili .org'''

urls = {}

for index, match in enumerate(url_pattern.finditer(content)):
    # print(index, match, match.start(), match.group())
    
    # index = (start, end, entity)
    urls[index] = (match.start(), match.end(), match.group())

print(urls)

# %%
content = '''SectionЛитература. , Христо Смирненски "Песни", Скопје, 1980. , Христо Смирненски "Избор", Скопје, 1998.
SectionНадворешни врски. , на Викиизвор. , Две песни од Смирненски на македонски, Уметност од Христо Смирненски 
на страницата www.slovo.bg, Уметност од Христо Смирненски на страницата liternet.bg
smeshno e superlongstring.com
lapajsi.com.mk, ahaha.com
slobodno odete na finki.ukim.mk
time.mk i mnogu drugi koi zavrshuvaat so mk ili .mk ili .org'''

urls = dict()
url_counter = 0
def fn_url_to_template_replace(match):
    global url_counter
    urls[url_counter] = (match.group(), match.start(), match.end())
    substitution = URL_TEMPLATE_STRING.format(url_counter)
    url_counter += 1
    return substitution

print(url_pattern.sub(fn_url_to_template_replace, content))
print()
print(urls)

# %%
content = '''Литература. , Христо Смирненски "Песни", Скопје, 1980. , Христо Смирненски "Избор", Скопје, 1998.
SectionНадворешни врски. , на Викиизвор. , Две песни од Смирненски на македонски, Уметност од Христо Смирненски 
на страницата [%__URL_0__%], Уметност од Христо Смирненски на страницата [%__URL_1__%]
smeshno e [%__URL_2__%]
[%__URL_3__%], [%__URL_4__%]
slobodno odete na [%__URL_5__%]
[%__URL_6__%] i mnogu drugi koi zavrshuvaat so mk ili .mk ili .org'''

template_to_url_counter = 0 
def fn_template_to_url_replace(match):
    global template_to_url_counter
    substitution = urls[template_to_url_counter][0]
    template_to_url_counter += 1
    return substitution

print(URL_TEMPLATE_REGEX.sub(fn_template_to_url_replace, content))
print()
print(urls)

# %%
content = '''Section::::Списък на песните в албума.
1. Искам да бъда
2. Жестока – с Невена Цонева
3. Нещо лично
4. Танцувай с мен
5. Мое щастие
6. Целуни ме
7. Това е
8. Дали съм жив
9. Кажи на майка си
10. Любовта е отрова – със Софи Маринова
11. Само мен
12. Не ме търси
13. Егати пича – с Краси Радков в ролята на Цеко Сифоня
14. Едно ченге

paragraph

Section::::Списък на песните в албума.
1. Искам да бъда
2. Жестока – с Невена Цонева
3. Нещо лично
4. Танцувай с мен
5. Мое щастие
6. Целуни ме
7. Това е
8. Дали съм жив
9. Кажи на майка си
10. Любовта е отрова – със Софи Маринова
11. Само мен
12. Не ме търси
13. Егати пича – с Краси Радков в ролята на Цеко Сифоня
14. Едно ченге

paragraph

Section::::Списък на песните в албума.
1. Искам да бъда
2. Жестока – с Невена Цонева
3. Нещо лично
4. Танцувай с мен
5. Мое щастие
6. Целуни ме
7. Това е
8. Дали съм жив
9. Кажи на майка си
10. Любовта е отрова – със Софи Маринова
11. Само мен
12. Не ме търси
13. Егати пича – с Краси Радков в ролята на Цеко Сифоня
14. Едно ченге'''

SectionEntityTemplate = EntityTemplate(entity_name='Section', 
               entity_regex=r'Section::::')

OrderedListEntityTemplate = EntityTemplate(entity_name='OrderedList',
              # entity_regex=r'[\d]+\. .*')
               # entity_regex=r'([\d]+\. .*[\r\n]*)')                            
               # entity_regex=r'([\d]+)(\. )(.*?)(?=([\d]+\.)|($))')
                entity_regex=r'([\d]+\..*[\r\n]*)')
content = OrderedListEntityTemplate.entity_to_template(content);
content = SectionEntityTemplate.entity_to_template(content)
print(content, os.linesep)
content = SectionEntityTemplate.template_to_entity(content)
content = OrderedListEntityTemplate.template_to_entity(content)
# print(content)

# %%
content = '''Section::::Списък на песните в албума.
1. Искам да бъда
2. Жестока – с Невена Цонева
3. Нещо лично
4. Танцувай с мен
5. Мое щастие
6. Целуни ме
7. Това е
8. Дали съм жив
9. Кажи на майка си
10. Любовта е отрова – със Софи Маринова
11. Само мен
12. Не ме търси
13. Егати пича – с Краси Радков в ролята на Цеко Сифоня
14. Едно ченге'''

re.findall(r'([\d]+)(\. )(.*?)(?=([\d]+\.)|($))', content)

# %%
def process_content(content):
    
    
    # processing
    parts = content.split(os.linesep)
    parts = list(map(lambda x: x.strip(), parts))
    
    bullet_flag = False
    bullet_marker = 'BULLET::::'
    bullet_list = list()
    bullet_start = 0
    bullet_end = 0
    
    for index, part in tqdm(enumerate(parts)):
        if bullet_marker in part:
            parts[index] = ', '.join(item.split(bullet_marker))
                
#     for part in parts[:50]:
#         print(f'START_{part}_END', os.linesep)
    content = os.linesep.join(parts)
    
    # post-processing
    content = replace_all(content, post_mapping)
    
    return content

# %%
#     'Св.': 'Свети',
#     'г.г.': 'Господин Господин',
#     'год.': 'година',
#     'г.': 'година',    
#     'и сл.': 'и слично.',
#     'итн.': 'и така натаму.',

# %%
    
    u'\u0020\u0020\u0020': ' ',
    u'\u00A0\u00A0\u00A0': ' ',
    u'\u2000\u2000\u2000': ' ',
    u'\u2001\u2001\u2001': ' ',
    u'\u2002\u2002\u2002': ' ',
    u'\u2003\u2003\u2003': ' ',
    u'\u2004\u2004\u2004': ' ',
    u'\u2005\u2005\u2005': ' ',
    u'\u2006\u2006\u2006': ' ',
    u'\u2007\u2007\u2007': ' ',
    u'\u2008\u2008\u2008': ' ',
    u'\u2009\u2009\u2009': ' ',
    u'\u200A\u200A\u200A': ' ',
    u'\u2028\u2028\u2028': ' ',
    u'\u205F\u205F\u205F': ' ',
    u'\u3000\u3000\u3000': ' ',
    
    u'\u0020\u0020': ' ',
    u'\u00A0\u00A0': ' ',
    u'\u2000\u2000': ' ',
    u'\u2001\u2001': ' ',
    u'\u2002\u2002': ' ',
    u'\u2003\u2003': ' ',
    u'\u2004\u2004': ' ',
    u'\u2005\u2005': ' ',
    u'\u2006\u2006': ' ',
    u'\u2007\u2007': ' ',
    u'\u2008\u2008': ' ',
    u'\u2009\u2009': ' ',
    u'\u200A\u200A': ' ',
    u'\u2028\u2028': ' ',
    u'\u205F\u205F': ' ',
    u'\u3000\u3000': ' ',

# %%
        if bullet_flag == False and bullet_marker in part:
            bullet_flag = True
            bullet_start = index #first occurence of a bullet
        
        if bullet_marker in part:
            bullet_list.append(part.replace(bullet_marker, ''))
            del parts[index]
        else:
            if bullet_flag == True:
                #Join and append to the big list
                bullet_flag = False
                bullet_end = index
                parts[bullet_start] = ', '.join(bullet_list)

# %%
            discards = list()
            print(len(parts))
            for index, part in tqdm(enumerate(parts)):
                if not part or len(part) == 0 or part == '' or '\r' in part or '\n' in part or part == None:
                    discards.append(part)
                    del parts[index]

                if 0 < len(part) <= 30 and part[len(part) - 1] == ':':
                    discards.append(part)
                    del parts[index]
            print(len(parts))
            
            print(discards)

# %%
            segments = list()
            for index, part in :
                if part == '':
                    continue
                    # segments.append(os.linesep)
                
                if 0 < len(part) <= 30 and part[len(part) - 1] == ':':
                    continue
                segments.append(part)
            
            content = os.linesep.join(segments)

# %%
for i in range(100):
    file_name = ''
    if(i <= 9):
        file_name = "wiki_0" + str(i)
    else:
        file_name = "wiki_" + str(i)

    with codecs.open(file_name, 'r', 'utf-8') as fin:
        with codecs.open(f'{file_name}_mod', 'w', 'utf-8') as fout:

            content = fin.read()
            content = w3lib.html.remove_tags(content)
            content = replace_all(content, mapping)
            content = replace_all(content, mapping)

            fout.write(content)
